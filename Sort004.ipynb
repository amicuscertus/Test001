# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from matplotlib import animation, rc
from IPython.display import HTML
 
n = 30
fig = plt.figure(figsize=(8, 6))
x = np.arange(n)
y = np.random.randint(0, 3 * n, n)
ims = []

def mysort(arr):
  n = len(arr)
  for i in range(n):
    max_value = arr[i:n].max()
    max_index = arr[i:n].argmax() + i
    arr[max_index] = arr[i]
    arr[i] = max_value
    line, = plt.plot(x, arr, 'r')
    ims.append([line])

mysort(y)
anim = animation.ArtistAnimation(fig, ims, interval=200)
rc('animation', html='jshtml')
anim
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img13d6087c6dc041d3beaf54a4a58f02dd">
#     <br>
#     <input id="_anim_slider13d6087c6dc041d3beaf54a4a58f02dd" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anim13d6087c6dc041d3beaf54a4a58f02dd.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim13d6087c6dc041d3beaf54a4a58f02dd.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anim13d6087c6dc041d3beaf54a4a58f02dd.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anim13d6087c6dc041d3beaf54a4a58f02dd.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anim13d6087c6dc041d3beaf54a4a58f02dd.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anim13d6087c6dc041d3beaf54a4a58f02dd.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anim13d6087c6dc041d3beaf54a4a58f02dd.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anim13d6087c6dc041d3beaf54a4a58f02dd.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anim13d6087c6dc041d3beaf54a4a58f02dd.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anim13d6087c6dc041d3beaf54a4a58f02dd.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_select13d6087c6dc041d3beaf54a4a58f02dd" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img13d6087c6dc041d3beaf54a4a58f02dd";
#     var slider_id = "_anim_slider13d6087c6dc041d3beaf54a4a58f02dd";
#     var loop_select_id = "_anim_loop_select13d6087c6dc041d3beaf54a4a58f02dd";
#     var frames = new Array(30);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDMuMC4zLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvnQurowAAIABJREFUeJzt3Xt0leWdL/DvTkK4JVxCAoQkJGBQ\
# LrkpiXSs9UgZapWKVhnJnF5otXXVM6fj1LFTe8Zzamd6TrE9tdrLmrM4dU1pV0+tY6fQ8VoVWyto\
# aYQgikSIICGQBBKScM9tnz9+Pu6XsHf2u9/3ee/fz1quLSHZeUl2sr/79/ye3xOLx+NxEBEREUVI\
# ltcXQEREROQ2BiAiIiKKHAYgIiIiihwGICIiIoocBiAiIiKKHAYgIiIiihwGICIiIoocBiAiIiKK\
# HAYgIiIiihwGICIiIoocBiAiIiKKHAYgIiIiihwGICIiIoocBiAiIiKKHAYgIiIiihwGICIiIooc\
# BiAiIiKKHAYgIiIiihwGICIiIoocBiAiIiKKHAYgIiIiihwGICIiIoocBiAiIiKKHAYgIiIiihwG\
# ICIiIoocBiAiIiKKHAYgIiIiihwGICIiIoocBiAiIiKKHAYgIiIiihwGICIiIoocBiAiIiKKHAYg\
# IiIiihwGICIiIoocBiAiIiKKHAYgIiIiihwGICIiIoocBiAiIiKKHAYgIiIiihwGICIiIoocBiAi\
# IiKKHAYgIiIiihwGICIiIoocBiAiIiKKHAYgIiIiihwGICIiIoocBiAiIiKKHAYgIiIiihwGICIi\
# IoocBiAiIiKKHAYgIiIiipwcry/A7woLC1FRUeH1ZRAREbni4MGDOH78uNeX4TgGoDQqKirQ1NTk\
# 9WUQERG5or6+3utLcAWXwIiIiChyGICIiIgochiAiIiIKHIYgIiIiChyGICIiIgochiAiIiIKHIY\
# gIiIiChyGICIiIgochiAiIiIKHIYgIiIiChyGICIiIgochiA3BSPA+++6/VVEBERRR4DkJv+6Z+A\
# xYuBvj6vr4SIiCjSGIDcdN11wPnzwObNXl8JERFRpDEAuWnZMqC8HHjsMa+vhIiIKNIYgNwUiwFr\
# 1wLPPw90d3t9NURERJHFAOS2xkZgaAj493/3+kqIiIgiiwHIbXV1wKWXchmMiIjIQwxAblPLYL//\
# PdDR4fXVEBERRRIDkBcaG4GREeCJJ7y+EiIiokhiAPLC4sVAVRXwq195fSVERESRxADklcZG4JVX\
# gLY2r6+EiIgochiAvLJ2rdw+/ri310FERBRBDEBeqawEli7lMhgREZEHGIC81NgI/PnPQGur11dC\
# REQUKQxAXrrtNrnlMhgREZGrGIC8NHcucNVVHIpIRETkMgYgrzU2Am+8Abz9ttdXQkREFBkMQF5b\
# s0amQ7MZmoiIyDUMQF4rLgauvVaWweJxr6+GiIgoEhiA/GDtWqClRZbCiIiIyHEMQH5w661Adjab\
# oYmIiFzCAOQHhYXAypVcBiMiInJJaAPQ97//fSxZsgRVVVX467/+a5w7dw4HDhzAsmXLUFlZibVr\
# 12JgYMDry0xYuxY4eFAGIxIREZGjQhmA2tvb8YMf/ABNTU148803MTw8jMceewxf+9rX8JWvfAX7\
# 9+/H9OnT8eijj3p9qQk33wzk5nIZjIiIyAWhDEAAMDQ0hLNnz2JoaAhnzpxBcXExtmzZgjVr1gAA\
# 1q1bh02bNnl8lQbTpgEf/7hMhR4Z8fpqiIiIQi2UAaikpAT33nsv5s6di+LiYkydOhVLly7FtGnT\
# kJOTAwAoLS1Fe3u7x1c6SmMj0N4ObN3q9ZUQERGFWigD0IkTJ7B582YcOHAAR44cwenTp/Hss8+a\
# /vgNGzagvr4e9fX1OHbsmINXOsqNNwITJ3IZjIiIyGGhDEAvvPAC5s2bh6KiIowbNw633HILtm7d\
# it7eXgwNDQEADh8+jJKSkqQff+edd6KpqQlNTU0oKipy78Lz8oBPfAJ44gng/esk

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from matplotlib import animation, rc
from IPython.display import HTML
 
n = 5
fig = plt.figure(figsize=(8, 6))
x = np.arange(n)
y = np.random.randint(0, 3 * n, n)
ims = []

def mysort(arr):
  n = len(arr)
  for i in range(n):
    max_value = arr[i:n].max()
    max_index = arr[i:n].argmax() + i
    print('arr = ', arr, end=', ')
    print('max_value = ', max_value, end=', ')
    print('max_index = ', max_index)
    arr[max_index] = arr[i]
    arr[i] = max_value
    line, = plt.plot(x, arr, 'r')
    ims.append([line])

mysort(y)
anim = animation.ArtistAnimation(fig, ims, interval=200)
rc('animation', html='jshtml')
anim
# Out:
# arr =  [13  2  5  4  3], max_value =  13, max_index =  0
# arr =  [13  2  5  4  3], max_value =  5, max_index =  2
# arr =  [13  5  2  4  3], max_value =  4, max_index =  3
# arr =  [13  5  4  2  3], max_value =  3, max_index =  4
# arr =  [13  5  4  3  2], max_value =  2, max_index =  4
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img11239789e98a4d8680852f05fe94a798">
#     <br>
#     <input id="_anim_slider11239789e98a4d8680852f05fe94a798" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anim11239789e98a4d8680852f05fe94a798.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim11239789e98a4d8680852f05fe94a798.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anim11239789e98a4d8680852f05fe94a798.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anim11239789e98a4d8680852f05fe94a798.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anim11239789e98a4d8680852f05fe94a798.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anim11239789e98a4d8680852f05fe94a798.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anim11239789e98a4d8680852f05fe94a798.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anim11239789e98a4d8680852f05fe94a798.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anim11239789e98a4d8680852f05fe94a798.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anim11239789e98a4d8680852f05fe94a798.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_select11239789e98a4d8680852f05fe94a798" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img11239789e98a4d8680852f05fe94a798";
#     var slider_id = "_anim_slider11239789e98a4d8680852f05fe94a798";
#     var loop_select_id = "_anim_loop_select11239789e98a4d8680852f05fe94a798";
#     var frames = new Array(5);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDMuMC4zLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvnQurowAAIABJREFUeJzt3Xl8lNWh//FvQowgAhJIAAkKGIWw\
# RhhBFBfAKCCbEJmHYgsCpdraVq29tfW2VntbKVev4lJb3AutyFZ2qOwIgjqAWFBxKVFWDQgICJJl\
# fn+cxsiPJSFk5szznM/79eKVazKF73MHZr5zznnOSYpGo1EBAAA4JNl2AAAAgHijAAEAAOdQgAAA\
# gHMoQAAAwDkUIAAA4BwKEAAAcA4FCAAAOIcCBAAAnEMBAgAAzqEAAQAA51CAAACAcyhAAADAORQg\
# AADgHAoQAABwDgUIAAA4hwIEAACcQwECAADOoQABAADnUIAAAIBzKEAAAMA5FCAAAOAcChAAAHAO\
# BQgAADiHAgQAAJxDAQIAAM6hAAEAAOdQgAAAgHMoQAAAwDkUIAAA4BwKEAAAcA4FCAAAOIcCBAAA\
