# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from matplotlib import animation, rc
from IPython.display import HTML
 
n = 30
fig = plt.figure(figsize=(8, 6))
x = np.arange(n)
y = np.random.randint(0, 3 * n, n)
ims = []

def mysort(arr):
  n = len(arr)
  for i in range(n):
    max_value = arr[i:n].max()
    max_index = arr[i:n].argmax() + i
    arr[max_index] = arr[i]
    arr[i] = max_value
    line, = plt.plot(x, arr, 'r')
    ims.append([line])

mysort(y)
anim = animation.ArtistAnimation(fig, ims, interval=200)
rc('animation', html='jshtml')
anim
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img0758c0a7539145d5a8a7918d39a92f5b">
#     <br>
#     <input id="_anim_slider0758c0a7539145d5a8a7918d39a92f5b" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anim0758c0a7539145d5a8a7918d39a92f5b.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim0758c0a7539145d5a8a7918d39a92f5b.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anim0758c0a7539145d5a8a7918d39a92f5b.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anim0758c0a7539145d5a8a7918d39a92f5b.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anim0758c0a7539145d5a8a7918d39a92f5b.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anim0758c0a7539145d5a8a7918d39a92f5b.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anim0758c0a7539145d5a8a7918d39a92f5b.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anim0758c0a7539145d5a8a7918d39a92f5b.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anim0758c0a7539145d5a8a7918d39a92f5b.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anim0758c0a7539145d5a8a7918d39a92f5b.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_select0758c0a7539145d5a8a7918d39a92f5b" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img0758c0a7539145d5a8a7918d39a92f5b";
#     var slider_id = "_anim_slider0758c0a7539145d5a8a7918d39a92f5b";
#     var loop_select_id = "_anim_loop_select0758c0a7539145d5a8a7918d39a92f5b";
#     var frames = new Array(30);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDMuMC4zLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvnQurowAAIABJREFUeJzt3Xt0VOW9N/DvkHAnIUgCuQEREjVc\
# o0ykb6utiKj1KGjCUXq0pYrlVNu+VutRTy+v9rZEa6lWu07LEZVjz5FjvYAtari1pbKKkCZeEJEg\
# EwyBxBAShJCQ27x//NwmhEkymdl7P8/ez/ezlmu4JDOPw2T2d37P5RcIh8NhEBERERlkkOoBEBER\
# EbmNAYiIiIiMwwBERERExmEAIiIiIuMwABEREZFxGICIiIjIOAxAREREZBwGICIiIjIOAxAREREZ\
# hwGIiIiIjMMARERERMZhACIiIiLjMAARERGRcRiAiIiIyDgMQERERGQcBiAiIiIyDgMQERERGYcB\
# iIiIiIzDAERERETGYQAiIiIi4zAAERERkXEYgIiIiMg4DEBERERkHAYgIiIiMg4DEBERERmHAYiI\
# iIiMwwBERERExmEAIiIiIuMwABEREZFxGICIiIjIOAxAREREZBwGICIiIjIOAxAREREZhwGIiIiI\
# jMMARERERMZhACIiIiLjMAARERGRcRiAiIiIyDgMQERERGQcBiAiIiIyDgMQERERGYcBiIiIiIzD\
# AERERETGYQAiIiIi4zAAERERkXEYgIiIiMg4DEBERERkHAYgIiIiMg4DEBERERmHAYiIiIiMwwBE\
# RERExklUPQDdpaamIicnR/UwiIiIXFFZWYkjR46oHobjGID6kZOTg9LSUtXDICIickUwGFQ9BFdw\
# CoyIiIiMwwBERERExmEAIiIiIuMwABEREZFxGICIiIjIOAxAREREZBwGICIiIjIOAxAREREZhwGI\
# iIiIjMMARERERMZhACIiIiLjMAC5qaUFOHwYCIdVj4SIiMhoDEBuevRRIDMTOHVK9UiIiIiMxgDk\
# pqQkuf3kE7XjICIiMhwDkJuSk+X2+HG14yAiIjIcA5CbWAEiIiLSAgOQm1gBIiIi0gIDkJtYASIi\
# ItICA5CbrAoQAxAREZFSDEBu4hQYERGRFnwbgH71q19h2rRpmD59Or7yla+gpaUFoVAIc+bMQW5u\
# Lm644Qa0tra6OyhOgREREWnBlwGouroav/71r1FaWopdu3aho6MDa9aswb333os777wT+/btw5gx\
# Y7Bq1Sp3BzZyJBAIsAJERESkmC8DEAC0t7ejubkZ7e3tOHnyJDIyMrBlyxYsWrQIALBkyRKsXbvW\
# 3UEFAlIFYgWIiIhIKV8GoKysLNx9992YOHEiMjIyMHr0aMyePRspKSlITEwEAGRnZ6O6utr9wSUn\
# swJERESkmC8DUENDA9atW4dQKIRDhw6hqakJr7/+etTfv3LlSgSDQQSDQdTV1dk7OFaAiIiIlPNl\
# ANq0aRPOPvtspKWlYfDgwSgqKsK2bdvQ2NiI9vZ2AMDBgweRlZUV8fuXLVuG0tJSlJaWIi0tzd7B\
# JSczABERESnmywA0ceJEbN++HSdPnkQ4HMbmzZsxdepUzJ07Fy+88AIAYPXq1Vi4cKH7g+MUGBER\
# kXK+DEBz5szBokWLcMEFF2DGjBno7OzEsmXL8NBDD2HFihXIzc1FfX09li5d6v7gOAVGRESkXCAc\
# DodVD0JnwWAQpaWl9t3hzTcDW7YABw7Yd59EREQ2sf26pylfVoC0xgoQERGRcgxAbrPWALHwRkRE\
# pAwDkNuSkoCODqC5WfVIiIiIjMUA5DZ2hCciIlKOAcht7AhPRESkHAOQ29gRnoiISDkGILexAkRE\
# RKQcA5DbWAEiIiJSjgHIbawAERERKccA5DZWgIiIiJRjAHIbt8ETEREpxwDktuHDgYQEToEREREp\
# xADktkCA/cCIiIgUYwBSweoHRkREREowAKnAChAREZFSDEAqsAJERESkFAOQCqwA

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from matplotlib import animation, rc
from IPython.display import HTML

n = 3
fig = plt.figure(figsize=(8, 6))
x = np.arange(n)
y = np.random.randint(0, 3 * n, n)
ims = []

def mysort(arr):
  n = len(arr)
  for i in range(n):
    max_value = np.max(arr[i:n])
    max_index = np.argmax(arr[i:n]) + i
    arr[max_index] = arr[i]
    arr[i] = max_value
    line, = plt.plot(x, arr, 'r')
    print(line)
    ims.append([line])

mysort(y)
anim = animation.ArtistAnimation(fig, ims, interval=200)
rc('animation', html='jshtml')
anim
# Out:
# Line2D(_line0)
# Line2D(_line1)
# Line2D(_line2)
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img44882e097bbe478381e065dfb835c2f5">
#     <br>
#     <input id="_anim_slider44882e097bbe478381e065dfb835c2f5" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anim44882e097bbe478381e065dfb835c2f5.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim44882e097bbe478381e065dfb835c2f5.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anim44882e097bbe478381e065dfb835c2f5.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anim44882e097bbe478381e065dfb835c2f5.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anim44882e097bbe478381e065dfb835c2f5.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anim44882e097bbe478381e065dfb835c2f5.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anim44882e097bbe478381e065dfb835c2f5.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anim44882e097bbe478381e065dfb835c2f5.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anim44882e097bbe478381e065dfb835c2f5.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anim44882e097bbe478381e065dfb835c2f5.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_select44882e097bbe478381e065dfb835c2f5" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img44882e097bbe478381e065dfb835c2f5";
#     var slider_id = "_anim_slider44882e097bbe478381e065dfb835c2f5";
#     var loop_select_id = "_anim_loop_select44882e097bbe478381e065dfb835c2f5";
#     var frames = new Array(3);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDMuMC4zLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvnQurowAAIABJREFUeJzt3Xt0VOWh/vFnTLgWiCSEVUw4Qhgv\
# 4RIiDIZjCwouqqCmVlDgZyFCIOBRbl6KFwRBBBRBUBCNUCBo5Q9QgzcsgrRHKqajXAq2lYvBJGIN\
# IFhUIAnv74/d5pgmQIDJvDN7fz9rsZLM3jM8rzvDPO7b6zPGGAEAAHjIBbYDAAAAhBsFCAAAeA4F\
# CAAAeA4FCAAAeA4FCAAAeA4FCAAAeA4FCAAAeA4FCAAAeA4FCAAAeA4FCAAAeA4FCAAAeA4FCA