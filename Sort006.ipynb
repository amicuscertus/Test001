# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from matplotlib import animation, rc
from IPython.display import HTML
 
n = 30
fig = plt.figure(figsize=(8, 6))
x = np.arange(n)
y = np.random.randint(0, 3 * n, n)
ims = []

def subset(work):
  last = work[-1]
  for i in range(len(work)-1):
    if last < work[i]:
      for j in range(len(work) - 1 - i):
        work[len(work) - 1 - j] = work[len(work) - 1 - j - 1]
      work[i] = last
      break
  return

def insertion_sort(arr):
  for i in range(2, len(arr) + 1):
    subset(arr[0:i])
    line, = plt.plot(x, arr, 'r')
    ims.append([line])

insertion_sort(y)
anim = animation.ArtistAnimation(fig, ims, interval=200)
rc('animation', html='jshtml')
anim
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img459c02959db647c5835abe32b4c4aaa2">
#     <br>
#     <input id="_anim_slider459c02959db647c5835abe32b4c4aaa2" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anim459c02959db647c5835abe32b4c4aaa2.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim459c02959db647c5835abe32b4c4aaa2.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anim459c02959db647c5835abe32b4c4aaa2.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anim459c02959db647c5835abe32b4c4aaa2.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anim459c02959db647c5835abe32b4c4aaa2.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anim459c02959db647c5835abe32b4c4aaa2.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anim459c02959db647c5835abe32b4c4aaa2.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anim459c02959db647c5835abe32b4c4aaa2.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anim459c02959db647c5835abe32b4c4aaa2.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anim459c02959db647c5835abe32b4c4aaa2.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_select459c02959db647c5835abe32b4c4aaa2" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img459c02959db647c5835abe32b4c4aaa2";
#     var slider_id = "_anim_slider459c02959db647c5835abe32b4c4aaa2";
#     var loop_select_id = "_anim_loop_select459c02959db647c5835abe32b4c4aaa2";
#     var frames = new Array(29);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDMuMC4zLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvnQurowAAIABJREFUeJzt3Xt4nVWdL/DvTtOmt1zappfYe2nR\
# thRKaako41BqhUFspVQsova0ICPjcRDkAZzjHHFGH+s4IiiMjx1RqwNUph5blcuxtii0wulELnLT\
# AZLQJm12r0mTNGlu7/nj52Kn6d7Jvrzr8r7r+3kentDS7rzsJHt/39/6rfVLBEEQgIiIiMgjRbYv\
# gIiIiMg0BiAiIiLyDgMQEREReYcBiIiIiLzDAERERETeYQAiIiIi7zAAERERkXcYgIiIiMg7DEBE\
# RETkHQYgIiIi8g4DEBEREXmHAYiIiIi8wwBERERE3mEAIiIiIu8wABEREZF3GICIiIjIOwxARERE\
# 5B0GICIiIvIOAxARERF5hwGIiIiIvMMARERERN5hACIiIiLvMAARERGRdxiAiIiIyDsMQEREROQd\
# BiAiIiLyDgMQEREReYcBiIiIiLzDAERERETeYQAiIiIi7zAAERERkXcYgIiIiMg7DEBERETkHQYg\
# IiIi8g4DEBEREXmHAYiIiIi8wwBERERE3mEAIiIiIu8wABEREZF3GICIiIjIOwxARERE5B0GICIi\
# IvIOAxARERF5hwGIiIiIvMMARERERN5hACIiIiLvMAARERGRdxiAiIiIyDsMQEREROQdBiAiIiLy\
# DgMQEREReafY9gW4rrKyEjNmzLB9GUREREbU1dXhyJEjti9DOwagQcyYMQPV1dW2L4OIiMiIxYsX\
# 274EI7gERkRERN5hACIiIiLvMAARERGRdxiAiIiIyDsMQEREROQdBiAiIiLyDgMQEREReYcBiIiI\
# iLzDAERERETeYQAiIiIi7zAAERERkXcYgIjIjiAAurpsXwVRtCWTwMmTtq8ikhiAiMi8U6eANWuA\
# +fPNfc5vfQs47zxzn4/IhNtvB84+2/ZVRBKnwRORWW1twFVXATt2yK97eoAhQ/R/3pdfln+CAEgk\
# 9H8+IhP+8AcG+zyxAkRE5pw4AVx+ObBzJ3DxxfJ7LS1mPndzM9DbC7S2mvl8RLq1tQGvvQZccIHt\
# K4kkBiAiMuPoUWD5cuDZZ4EtW4B16+T3T5ww8/nV52lqMvP5iHR78UUJ9QxAeWEAIiL9GhuBSy4B\
# XnoJ2LYN+MhHgPJy+W/NzWauQX0eBiCKi+pq+bh4sd3riCj2ABGRXvv2Ae9/P3DgAPDYY8Cll8rv\
# MwARFeYPfwAmTgTe8Q7bVxJJrAARkT5vvAH81V8Bhw4Bv/51KvwAqQDEJTC79u8Hdu+2fRWUjz/8\
# QZa/2NSfFwYgItLj1VeB971PGjV37QLe857T/3tZmXw0XQEy9fmi4o47gGXLpJmWooMN0AVjACKi\
# 8D33nIQfAHjqKWDRojP/jMklsK6u1GFxrAClBIF8fbq7gc9+Vn5N0cAG6IIxABFRuH7/e6kojB4N\
# PP00MG9e+j9nMgD1XWZjAErZtw9oaJA30Z07gf/8T9tXRNliA3TBGICIKDw7dwIrVkhj5tNPA2ed\
# lfnPjhwpByCa6AFiAEpvzx75+L3vAeefD9x6K89Jigo2QBeMAYiIwvGrXwEf/CAwa5Ysq0ydOvCf\
# TySkD8hEBajv52AAStm9GygtBRYuBO6/X6pB//zPtq+KssEG6IIxABFR4R55RMZbLFgA/Pa3wKRJ\
# 2f298nLzAYhN0Cm7dwMXXSSVuIsuAjZsAO6+mw3RrmMDdCgYgIgof0EA3HsvcO218ga6cycwblz2\
# f990ACopYQVIaWqS2WhqJAkAbNwovVtsiHYbG6BDwQBERPlJJmXJ63OfA668EnjiidTW9myVl5vt\
# AZo6lQFIeeYZCTl9A9D48cBXv8qGaNexAToUDEBElLvHHgPOPRd48kngvvtkvMXI
